# %% [markdown]
# <a href="https://colab.research.google.com/github/smit-collab/Intern-tasks/blob/master/Task_4_To_Explore_Decision_Tree_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
import sklearn.datasets as datasets

# %%
# reading the data
iris_data = datasets.load_iris()

# %%
df=pd.DataFrame(iris_data.data, columns = iris_data.feature_names)
print(df.head(5))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# creating the decision tree 
model = DecisionTreeClassifier().fit(iris_data.data,iris_data.target)
# model
plt.figure(figsize=(18,8))
plot_tree(model,filled=True)
plt.show()

# %% [markdown]
# feeding the data and classifier will predict the class

# %%
model.predict([[7,3.3,4.5,1.5]]) # prediction for a sample
# Out:
# array([1])

# %% [markdown]
# references:
#
# 1. Decision Trees, https://scikit-learn.org/stable/modules/tree.html#decision-trees
#
# 2. Learning Data Science: Day 21 - Decision Tree on Iris Dataset, https://medium.com/@haydar_ai/learning-data-science-day-21-decision-tree-on-iris-dataset-267f3219a7fa
#
# 3. Using Scikit-learn to Implement a Simple Decision Tree Classifier, https://www.kaggle.com/chrised209/decision-tree-modeling-of-the-iris-dataset
